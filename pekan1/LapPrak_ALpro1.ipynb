# %% [markdown]
# konten_sampul = """<div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Pengenalan Git & GitHub serta Dasar Pemrograman Python”**
#
# **Disusun Oleh :**
#
# **Gilang Adhatul Sukri**
#
# **2611532016**
#
# **Dosen Pengampu:**
#
# **Dr. Ir. Wahyudi, S.T., M.T.**
#
# **Asisten Praktikum:**
#
# **Rifki Yuliandra**
#
# <br>
#
# <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>
# """

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum ... yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan Pengenalan Git & GitHub
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung Git & GitHub pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ## BAB I : PENDAHULUAN
#
# ### 1.1 Latar Belakang
# Dalam pengembangan perangkat lunak modern dan pengelolaan proyek struktur data, sistem kontrol versi (*version control system*) seperti **Git** serta platform kolaborasi **GitHub** merupakan perkakas utama yang wajib dikuasai. Git memungkinkan pengembang untuk mencatat setiap perubahan kode program secara terstruktur, sedangkan GitHub berfungsi sebagai repositori jarak jauh (*remote repository*) untuk menyimpan dan mendokumentasikan proyek secara daring.
#
# Selain itu, bahasa pemrograman **Python** dipilih sebagai sarana implementasi pada praktikum Struktur Data karena sintaksisnya yang intuitif, bersih, dan mudah dipahami, sehingga praktikan dapat berfokus pada logika algoritma serta struktur data dasar.
#
# ### 1.2 Tujuan Praktikum
# 1. Memahami tata cara instalasi dan konfigurasi dasar Git dan GitHub pada PC.
# 2. Mampu membuat repositori lokal dan menghubungkannya ke repositori GitHub.
# 3. Memahami dan mengaplikasikan perintah dasar Git seperti `git init`, `git add`, `git commit`, dan `git push`.
# 4. Memahami dasar sintaksis bahasa pemrograman Python seperti komentar, cetak teks (`print()`), penggabungan string (*string concatenation*), dan penggunaan *escape character*.
#
# ### 1.3 Manfaat Praktikum
# 1. **Pengelolaan Kode yang Terstruktur:** Praktikan mampu mendokumentasikan dan memantau riwayat perubahan kode program secara rapi menggunakan Git.
# 2. **Keterampilan Kolaborasi:** Memahami penggunaan GitHub sebagai fondasi untuk melakukan manajemen proyek dan kolaborasi pengembangan perangkat lunak di masa depan.
# 3. **Penerapan Dasar Pemrograman:** Menambah pemahaman dasar dalam menulis sintaksis Python yang bersih dan sesuai aturan format teks sebelum memasuki konsep struktur data yang lebih kompleks.
# """

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Konfigurasi dan Alur Kerja Git & GitHub serta membuat kode sederhana menyesuaikan nama dan nim mahasiswa
# pratikum pekan 1 ini fokus pada instalasi dan set up akun github lalu menyambungkan akun tersebut pada vscode agar kita bisa commit dan push kode ke github:
#
# 1. instalsi github dan extensions python
# 2. pembuatan akun github dan menghubungkannya pada vcsode
# 3. commit dan push kode ke girhub

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "KelasC_2611532016"

# %%
### program pertama
""""
Komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("HEllo world")
print()
print("Departemen Informatika")
print("Universitas Andalas")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + " dibuat oleh a\\n "
+ "gilang adhatul sukri 2611532016")
# Out:
# Running cells with 'Python 3.13.15' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/AXIOO/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# **Penjelasan :**
# 1. kode Kode Python tersebut terdiri dari tiga bagian utama:
#
# 1. Multi-line Comment (Komentar Banyak Baris)
# Teks di dalam tiga tanda petik ganda (""" ... """) di awal kode adalah komentar. Bagian ini diabaikan oleh Python saat program dijalankan dan berfungsi sebagai catatan atau dokumentasi (menjelaskan bahwa ini tugas Praktikum Alpro Pertemuan 1).
#
# 2. Cetak Teks dan Baris Kosong
#
# print("HEllo world"): Menampilkan teks HEllo world ke layar.
#
# print(): Menampilkan baris kosong.
#
# print("Departemen Informatika") & print("Universitas Andalas"): Menampilkan nama departemen dan universitas pada barisnya masing-masing.
#
# 3. Karakter Khusus dan Penggabungan String
#
# print("/ \\ // \\\\ /// \\\\\\"): Menampilkan pola garis miring. Karakter backslash (\) merupakan escape character di Python, sehingga untuk menampilkan satu backslash nyata di layar, kamu harus menuliskan dua backslash (\\).
#
# print("program ini" + " dibuat oleh a\\n " + "gilang adhatul sukri 2611532016"): Menggabungkan tiga potongan teks menggunakan operator +. Di dalamnya terdapat \\n, yang karena menggunakan dua backslash, Python akan mencetak karakter \n secara mentah alih-alih membuat baris baru.

# %% [markdown]
# ### 2.2.2 Program Driver "Gilang_2611532016"
#
# Program driver ini dibuat untuk menguji dan menjalankan eksekusi perintah dasar Python, seperti pengujian keluaran teks, penggabungan string, serta penggunaan escape character dalam satu kesatuan file utama.
#
# #### A. Kode Program Driver (`Gilang_2611532016.py`)
# ```python
# # Program Driver - Gilang Adhatul Sukri (2611532016)

# %%
print("HEllo world")
print()
print("Departemen Informatika")
print("Universitas Andalas")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + " dibuat oleh a\\n "
+ "gilang adhatul sukri 2611532016")

# %% [markdown]
# Penjelasan program driver di atas: ...
#
# Program driver ini dibuat untuk menguji dan menjalankan eksekusi perintah dasar Python, seperti pengujian keluaran teks, penggabungan string, serta penggunaan escape character dalam satu kesatuan file utama.
#
# <div align="center">
# <img src="images/output1.png" width="400"><br>
# <em>Gambar 2.1 : Output Program</em>
# </div>

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :menginstal dan set up akun github ke vscode dan menulis kode lalu menyesuaikannya dengan nama dan nim masing masing mahasiswa**
#
# <div align="center">
# <img src="images/12.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "KELASC_2611532016"

# %%
print("HEllo world")
print()
print("Departemen Informatika")
print("Universitas Andalas")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + " dibuat oleh a\\n "
+ "gilang adhatul sukri 2611532016")

# %% [markdown]
# b. Kode Program Driver "NamaDriver_NIM"

# %%
# Kode jawaban tugas bagian b (driver)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_tugas.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :** Program tugas ini dimana mahasiswa mengetik algorima yg sudah dicontohkan dan menyesuaikannya dengan nama dan nim mahasiswa masing masing

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Dari pelaksanaan praktikum Pertemuan 1 ini, dapat ditarik beberapa kesimpulan:
# 1. **Konfigurasi Lingkungan Kerja:** Instalasi Python yang ditambahkan ke *PATH* serta penggunaan VS Code dan Git/GitHub mempermudah alur kerja pengembangan program secara terstruktur dan terintegrasi.
# 2. **Kontrol Versi:** Penggunaan Git dan GitHub efisien untuk mencatat riwayat perubahan kode melalui alur `git add`, `git commit`, dan `git push`.
